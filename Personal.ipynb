# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # Hello, I'm Enny
#
# ## Hello, I'm Enny
#
# ### Hello, I'm Enny
#
# #### Hello, I'm Enny
#
# I'm An Aspiring Data Science

# %%
# Step 1: Store the User's name 
Student_name = "Enny Lois"

# Step 2: Store the course name
Course_name = 'Data Science.'

# Step 3: Store the App used to learn the course
App_name = ["Visual Studio Code.","Python.","GitHub.","Publica Academy."]

print("Welcome!", Student_name)
print('You are erolled in:', Course_name)
print("You will enjoy learning but it will be challenging.")
print('During the period of learning, you will be conversant with the following apps:') 
for App in App_name:
    print(' -', App)
print("Let's start coding and learning together!")
# Out:
# Welcome! Enny Lois
# You are erolled in: Data Science.
# You will enjoy learning but it will be challenging.
# During the period of learning, you will be conversant with the following apps:
#  - Visual Studio Code.
#  - Python.
#  - GitHub.
#  - Publica Academy.
# Let's start coding and learning together!

# %%
# Step 1: Store the User's name 
Student_name = "Eniola Lois"

# Step 2: Store the course name
Course_name = 'Data Science.'

# Step 3: Store the App used to learn the course
App_name = ("Visual Studio Code,"" Python,"" GitHub,"" Publica Academy.")

print("Welcome!", Student_name)
print('You are erolled in:', Course_name)
print("You will enjoy learning but it will be challenging.")
print('During the period of learning, you will be conversant with the following apps:', App_name) 
print("Let's start coding and learning together!")
# Out:
# Welcome! Eniola Lois
# You are erolled in: Data Science.
# You will enjoy learning but it will be challenging.
# During the period of learning, you will be conversant with the following apps: Visual Studio Code, Python, GitHub, Publica Academy.
# Let's start coding and learning together!

# %%
print(3+2)
print('5'+'2')
print("2+9")
# Out:
# 5
# 52
# 2+9

# %%
print("Total:", sum([3,8]))

# Student Exam Scores
Exam_scores = [40, 50, 60, 70, 80, 85, 90, 95, 100, 200]
# Calculate the average score
# formula for average = sum of all scores / number of scores
Average = sum(Exam_scores) / len(Exam_scores)
print("Average_scores:", Average)
# Out:
# Total: 11
# Average_scores: 87.0

# %%
# LEN CODE SAMPLE OUTPUT
Text = "Welcome, we miss you!"

Course = ["Data Analysis", "Data Science", "Cybersecurity", "Robotics"]

Identity = {"username":"Enny Lois", "Occupation":"Doctor", "Location":"Lagos"}

Set_List =[3, 4, 5, 7, 8, 9, 1, 12]

print(len(Text))
print(len(Course))
print(len(Identity))
print(len(Set_List))
# Out:
# 21
# 4
# 3
# 8
